# %% [markdown]
# # Choosing the correct Model

# %% [markdown]
# ##### Note: -
#
# 1. Sklearn refers machine learning algorithm as estimaters.
# 2.  Classification : - Divides in category. Yes/No
# 3.  Regression: - Gives approximation value. Example: - Selling price of house
#
# [Model Reference ](https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html)

# %%
from sklearn.datasets import fetch_california_housing
df = fetch_california_housing()

df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sks

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
housing = pd.DataFrame(df.data,columns = df.feature_names)
housing
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
housing['MedHouseVal'] = df.target
housing
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %% [markdown]
# Splitting Datas

# %%
x = housing.drop("MedHouseVal", axis = 1)
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y = housing["MedHouseVal"]
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
x.shape, y.shape
# Out:
# ((20640, 8), (20640,))

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

x_train, y_train
# Out:
# (       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  4336   2.1766      36.0  2.835556   1.117778      1502.0  3.337778     34.08
#  12142  4.0833       2.0  7.416667   1.307292       681.0  3.546875     33.83
#  15410  2.1293       9.0  4.735238   1.192381      1938.0  3.691429     33.21
#  15305  1.8214      23.0  3.457456   1.073294      4729.0  3.983993     33.19
#  14386  3.4286       5.0  4.281690   1.194836       892.0  2.093897     32.75
#  ...       ...       ...       ...        ...         ...       ...       ...
#  3812   3.3864      25.0  4.436055   1.114022      2077.0  3.200308     34.21
#  18125  7.4863      23.0  6.585023   1.046802      1782.0  2.780031     37.33
#  19396  2.9125      21.0  5.240964   1.156627       219.0  2.638554     37.76
#  1949   2.5625      15.0  5.341463   1.045296       674.0  2.348432     38.75
#  8740   4.3056      30.0  5.036932   1.011364       905.0  2.571023     33.81
#
#         Longitude
# ...

# %%
x_train.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
x_test.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
y_train.isna().sum(), y_test.isna().sum()
# Out:
# (0, 0)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 4336 to 8740
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      16512 non-null  float64
#  1   HouseAge    16512 non-null  float64
#  2   AveRooms    16512 non-null  float64
#  3   AveBedrms   16512 non-null  float64
#  4   Population  16512 non-null  float64
#  5   AveOccup    16512 non-null  float64
#  6   Latitude    16512 non-null  float64
#  7   Longitude   16512 non-null  float64
# dtypes: float64(8)
# memory usage: 1.1 MB

# %% [markdown]
# Ridge Model

# %%
from sklearn.linear_model import Ridge

model1 = Ridge()

model1.fit(x_train, y_train)
# Out:
# Ridge()

# %%
model1.score(x_test, y_test)
# Out:
# 0.6173259487015534

# %%
model1.score(x_train, y_train)
# Out:
# 0.6033932096182206

# %% [markdown]
# svr model

# %%
from sklearn.svm import SVR

model2 = SVR()

model2.fit(x_train, y_train)
# Out:
# SVR()

# %%
model2.score(x_test, y_test)
# Out:
# -0.02818688209598208

# %%
model2.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# Lesso

# %%
from sklearn.linear_model import Lasso

model3 = Lasso()

model3.fit(x_train,y_train)
# Out:
# Lasso()

# %%
model3.score(x_test,y_test)
# Out:
# 0.29256709606986797

# %% [markdown]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

model4 = RandomForestRegressor()

model4.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model4.score(x_test, y_test)
# Out:
# 0.814601385128325
