# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceRaj1161/Complete-A.I.-Machine-Learning-Data-Science-Bootcamp/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# There are three types of Machine Learning: -

"""
i) Supervised
ii) Unsupervised
iii) Reinforcemrnt



"""
# Out:
# '\ni) Supervised \nii) Unsupervised \niii) Reinforcemrnt \n\n\n\n'

# %%
# Framework for Machine Learning

"""
i) Create a framework
ii) Match to data science and machine learning tools
iii) Learn by doing
"""
# Out:
# '\ni) Create a framework \nii) Match to data science and machine learning tools\niii) Learn by doing\n'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
